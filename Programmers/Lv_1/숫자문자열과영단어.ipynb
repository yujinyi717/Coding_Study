# %% [markdown]
# 1. 문제링크
# - https://programmers.co.kr/learn/courses/30/lessons/81301

# %% [markdown]
# 2. 아이디어 정리

# %%
# ! pip install pillow
from PIL import Image

image1 = Image.open(r'C:/Users/wlsdl/OneDrive/문서/카카오톡 받은 파일/image.jpg')
image1.resize((450, 600))

# join 함수 학습
# Out:
# <PIL.Image.Image image mode=RGB size=450x600 at 0x2D6033B6070>

# %% [markdown]
# 3. 문제 풀이

# %%
# sol 1 ) enumerate, split으로 분리 후 join으로 합치기 

def solution(s):
    
    num_list = ['zero','one','two','three','four','five','six','seven','eight','nine']
    for i,j in enumerate(num_list):
        s = str(i).join(s.split(j)) # 주의 int를 여기다 붙이면 안된다 ! 
    
    return(int(s))

solution('2three45sixseven')
# Out:
# 234567

# %%
# sol 2) dict 의 items()로 불러서, replace 사용

def solution(s):
    
    num_dict = {'zero': '0' ,'one': '1', 'two' : '2', 'three' : '3', 'four' : '4', 'five' : '5' ,'six' : '6', 'seven' : '7', 'eight' : '8', 'nine' : '9'}
    for key,value in num_dict.items():
        s = s.replace(key,value)
    
    return(int(s))
solution('2three45sixseven')
# Out:
# 234567
